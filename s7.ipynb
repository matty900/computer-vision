# %%
'''
ROTATION is not done like resizing by built-in functions
is is acheived using transformation metrics (rotation matrix)
cv2.getRotationMatrix2D(center, angle, scale)
such as:
[6      2     4        [ 4  - 2 1] = [24 -9 23]
-1      4     3     * 
-2      9     3]
Standatrd 2D rotation matrix for counterclockwise
BUT: for cv is different, it's clockwise 
R = [[ cosθ sinθ (1−cosθ⋅s)⋅cx-sinθ⋅s⋅cy] # the first two perameter is for image - the last one is for frame aound the image rotation

'''

# %%
import cv2;
import numpy as np;
import matplotlib.pyplot as plt

# %%
# Main solution
image = cv2.imread("Dog and Cat.jpg")
cv2.imshow('frame', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Second solution
image = cv2.imread("Dog and Cat.jpg")
cv2.namedWindow("frame", cv2.WINDOW_NORMAL)  # Allows resizing
cv2.imshow("frame", image)

cv2.waitKey(0)  # Press any key to close
cv2.destroyAllWindows()

# %%
# Third solution using matplot to display the image inside jupyter
image = cv2.imread("Dog and Cat.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB

(h, w) = image.shape[:2] # no need for third channed

center_x = w /2
center_y = h/ 2

center = (center_x, center_y)

angel = 90 
scale = 1.0   # 1.0 means don't make change on image

rotation_matrix = cv2.getRotationMatrix2D(center, 90, 1)  # FIRST; getting rotation matrix of the image
print(rotation_matrix)  


plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# [[ 6.12323400e-17  1.00000000e+00 -1.13686838e-13]
#  [-1.00000000e+00  6.12323400e-17  1.20000000e+03]]
